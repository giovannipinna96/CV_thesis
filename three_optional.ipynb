# %%
import cv2 as cv2
import glob
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras import optimizers, initializers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Flatten,Dropout, MaxPooling2D, AveragePooling2D
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.callbacks import EarlyStopping, History
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.vgg16 import VGG16

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

import import_ipynb
import dataSetUtility as dsu
import plottingUtility as pltu
# Out:
# importing Jupyter notebook from dataSetUtility.ipynb
# importing Jupyter notebook from plottingUtility.ipynb

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

from keras.utils import np_utils
from tensorflow.keras.applications import VGG16, imagenet_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
import imageio
from PIL import Image
import tifffile

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
import seaborn as sn
import numpy as np
from scipy import ndimage

import random
import PIL
import os
import cv2 as cv2
import itertools
import glob

# %%
#path to the directories
pathTrain=r'C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train'
pathTest=r'C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\test'

labels = [os.path.basename(i) for i in glob.glob(pathTrain + '/*', recursive=True)]
numberOfClasses = len(labels)
print("Class number: ", numberOfClasses)
print("Class names: ", labels)
# Out:
# Class number:  12
# Class names:  ['171', '178_FORSE', '371', '385_FORSE', '43', '438', '619', '655', '659', '72', '96', 'Grandi']

# %%
def get_random_crop(img, width, height, dim=64):
    assert img.shape[0] >= height
    assert img.shape[1] >= width
    x = random.randint(0, img.shape[1] - width)
    y = random.randint(0, img.shape[0] - height)
    img = img[y:y+height, x:x+width]
    resImg = cv2.resize(img, (dim,dim), interpolation=cv2.INTER_CUBIC)
    return resImg

# %%
import math
import copy

def warpAffine(src, M, dsize, from_bounding_box_only=False):
    """
    Applies cv2 warpAffine, marking transparency if bounding box only
    The last of the 4 channels is merely a marker. It does not specify opacity in the usual way.
    """
    return cv2.warpAffine(src, M, dsize)

def rotate_image(image, dim=64):
    """Rotate the image counterclockwise.
    Rotate the image such that the rotated image is enclosed inside the
    tightest rectangle. The area not occupied by the pixels of the original
    image is colored black.
    Parameters
    ----------
    image : numpy.ndarray
        numpy image
    angle : float
        angle by which the image is to be rotated. Positive angle is
        counterclockwise.
    Returns
    -------
    numpy.ndarray
        Rotated Image
    """
    angle = random.randint(0, 360)
    # get dims, find center
    (h, w) = image.shape[:2]
    (cX, cY) = (w // 2, h // 2)

    # grab the rotation matrix (applying the negative of the
    # angle to rotate clockwise), then grab the sine and cosine
    # (i.e., the rotation components of the matrix)
    M = cv2.getRotationMatrix2D((cX, cY), angle, 1.0)
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])

    # compute the new bounding dimensions of the image
    nW = int((h * sin) + (w * cos))
    nH = int((h * cos) + (w * sin))

    # adjust the rotation matrix to take into account translation
    M[0, 2] += (nW / 2) - cX
    M[1, 2] += (nH / 2) - cY

    # perform the actual rotation and return the image
    image = warpAffine(image, M, (nW, nH), False)

    resImg = cv2.resize(image, (dim,dim), interpolation=cv2.INTER_CUBIC)

    return resImg

# %%
def dataAugmentationWithCropRot(path, labels, dimension=64, d=1):
    x = [] #New ImageSet
    y = [] #New Label
    for index,name in enumerate(labels):
        s = path+'/'+name+'/{}'
        s2 = path+'/'+name+'/'
        temp = [s.format(i) for i in os.listdir(path+'/'+name+'/')]
        q=0
        for image in temp:
            q = q+1
            tmp = cv2.resize(cv2.imread(image,cv2.IMREAD_GRAYSCALE),(dimension,dimension),interpolation=cv2.INTER_CUBIC)
            x.append(tmp)
            imageio.imwrite(s2 + 'outfile1' + str(q) + str(index) + '.jpg', tmp)
            q = q+1
            x.append(cv2.flip(tmp,1))
            imageio.imwrite(s2+ 'outfile2' + str(q)  + str(index)+  '.jpg', cv2.flip(tmp,1))
            q = q+1
            x.append(get_random_crop(tmp, dimension-24, dimension-24, dimension))
            imageio.imwrite(s2+ 'outfile3' + str(q)+   str(index) + '.jpg', get_random_crop(tmp, dimension-24, dimension-24, dimension))
            q = q+1
            x.append(rotate_image(tmp, dimension))
            imageio.imwrite(s2+ 'outfile4' + str(q) + str(index)+ '.jpg', rotate_image(tmp, dimension))
            q = q+1
            y.append(index)
            y.append(index)
            y.append(index)
            y.append(index)
        
    x = np.asarray([np.reshape(im, (dimension, dimension, d)) for im in x])
    x=x/255
    y = np.asarray(y)
    return x,y

# %%
#xTrain, yTrain = dataAugmentationWithCropRot(pathTrain, labels, dimension=224)

# %%
#xTrain.shape

# %%
xTrain, yTrain = dataAugmentationWithCropRot(pathTrain, labels, dimension=128, d=1)
xTest, yTest = dsu.loadImages(pathTest, labels, dimension=128)

# %%
yTrainDummy = to_categorical(yTrain, 12)
yTestDummy = to_categorical(yTest, 12)

# %%
model = VGG16(weights='imagenet', include_top=False)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
def extractFeatures(model, path, labels):
    
    pathImages = []
    for label in labels:
        s = path+'/'+label+'/{}'
        temp = [s.format(i) for i in os.listdir(path+'/'+label+'/')]
        pathImages = pathImages + temp
    
    res = []
    count = 0
    for p in pathImages:
        count += 1
        img = load_img(p, target_size=(128,128))
        print(p)
        img = img_to_array(img)
        img = np.expand_dims(img, axis=0)
        img = imagenet_utils.preprocess_input(img)
        res.append(img)
        
    images = np.vstack(res)
    features = model.predict(images, batch_size=64)
    featuresFlatten = features.reshape((features.shape[0], 7 * 7 * 512))
    
    return images, features, featuresFlatten

# %%
trainImages, featureMatrix, featureArray = extractFeatures(model, pathTrain, labels)
# Out:
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0066_Livello 67.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0067_Livello 68.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0068_Livello 69.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0070_Livello 71.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0071_Livello 72.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0072_Livello 73.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0073_Livello 74.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0075_Livello 76.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0076_Livello 77.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0078_Livello 79.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0079_Livello 80.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0080_Livello 81.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0082_Livello 83.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0083_Livello 84.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0084_Livello 85.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0085_Livello 86.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0086_Livello 87.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0088_Livello 89.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0089_Livello 90.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0090_Livello 91.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0091_Livello 92.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0092_Livello 93.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0094_Livello 95.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0095_Livello 96.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0096_Livello 97.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0097_Livello 98.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0098_Livello 99.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0099_Livello 100.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0100_Livello 101.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0102_Livello 103.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0103_Livello 104.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0104_Livello 105.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0105_Livello 106.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/10_Memmi_S_Francesco_1000dpi_rit_0106_Livello 107.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile110.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11010.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11060.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1110.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11110.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11160.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11210.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11260.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11310.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11360.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11410.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11460.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11510.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11560.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1160.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11610.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile11660.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1210.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1260.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1310.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1360.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1410.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1460.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1510.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1560.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile160.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1610.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1660.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1710.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1760.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1810.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1860.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1910.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile1960.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21020.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21070.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21120.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21170.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2120.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21220.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21270.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21320.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21370.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21420.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21470.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21520.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21570.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21620.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile21670.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2170.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile220.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2220.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2270.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2320.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2370.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2420.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2470.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2520.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2570.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2620.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2670.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile270.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2720.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2770.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2820.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2870.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2920.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile2970.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31030.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31080.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31130.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31180.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31230.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31280.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3130.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31330.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31380.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31430.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31480.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31530.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31580.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31630.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile31680.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3180.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3230.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3280.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile330.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3330.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3380.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3430.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3480.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3530.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3580.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3630.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3680.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3730.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3780.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile380.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3830.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3880.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3930.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile3980.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41040.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41090.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41140.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41190.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41240.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41290.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41340.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41390.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4140.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41440.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41490.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41540.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41590.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41640.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile41690.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4190.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4240.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4290.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4340.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4390.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile440.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4440.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4490.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4540.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4590.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4640.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4690.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4740.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4790.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4840.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4890.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile490.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4940.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/171/outfile4990.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0000_Livello 1.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0000_Livello 24.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0000_Livello 61.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0001_Livello 2.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0001_Livello 25.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0001_Livello 62.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0002_Livello 26.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0002_Livello 3.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0002_Livello 63.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0003_Livello 27.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0003_Livello 4.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0003_Livello 64.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0004_Livello 28.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0004_Livello 5.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0005_Livello 29.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0005_Livello 6.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_0005_Livello 66.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/178_FORSE/10_Memmi_S_Francesco_1000dpi_rit_
tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/10_Memmi_S_Francesco_1000dpi_rit_0016_Livello 17.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/10_Memmi_S_Francesco_1000dpi_rit_0017_Livello 18.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/10_Memmi_S_Francesco_1000dpi_rit_0018_Livello 19.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/10_Memmi_S_Francesco_1000dpi_rit_0020_Livello 21.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/10_Memmi_S_Francesco_1000dpi_rit_0021_Livello 22.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/10_Memmi_S_Francesco_1000dpi_rit_0022_Livello 23.tif
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile1111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile11111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile11611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile12111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile12611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile13111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile13611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile14111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile14611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile15111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile15611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile1611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile16111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile16611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile17111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile17611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile18111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile18611.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile19111.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile21211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile21711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile2211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile22211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile22711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile23211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile23711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile24211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile24711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile25211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile25711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile26211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile26711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile2711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile27211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile27711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile28211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile28711.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile29211.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile31311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile31811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile32311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile32811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile3311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile33311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile33811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile34311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile34811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile35311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile35811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile36311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile36811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile37311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile37811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile3811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile38311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile38811.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile39311.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile41411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile41911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile42411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile42911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile43411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile43911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile4411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile44411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile44911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile45411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile45911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile46411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile46911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile47411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile47911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile48411.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile48911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile4911.jpg
# C:\Users\39320\Desktop\tesi\Computer-Vision-2020-main\ImageSet\train/Grandi/outfile49411.jpg

# %%
testImages, featureMatrixTest, featureArrayTest = extractFeatures(model, pathTest, labels)

# %%
classif = [SVC(kernel="linear") for _ in range(numberOfClasses)]

currentLabel = 0
for clf in classif:
    print(currentLabel)
    v = np.array([1 if label==currentLabel else 0 for label in yTrain])
    clf = clf.fit(featureArray, v)
    currentLabel += 1

# %%
prediction = []
for image in featureArrayTest:
    pred = np.array([np.dot(clf.coef_,image) + clf.intercept_ for clf in classif])
    prediction.append(np.argmax(pred))
    
prediction = np.asarray(prediction)

# %%
cont=0
for i in range(len(prediction)):
    if prediction[i]==yTest[i]:
        cont += 1
    else:
        continue
        
accuracy = cont/len(prediction)
print("Accuracy value: ",accuracy)

# %%
tp = []
fp = []
fn = []
tn = []
for i in range(numberOfClasses):
    tp_temp = 0
    fp_temp = 0
    fn_temp = 0
    tn_temp = 0
    
    for j in range(len(prediction)):
        if(prediction[j]==i and yTest[j]==i):
            tp_temp += 1
        if(prediction[j]==i and yTest[j]!=i):
            fp_temp += 1
        if(prediction[j]!=i and yTest[j]==i):
            fn_temp += 1
        if(prediction[j]!=i and yTest[j]!=i):
            tn_temp += 1
    tp.append(tp_temp)
    fp.append(fp_temp)
    fn.append(fn_temp)
    tn.append(tn_temp)

# %%
data = {'labels':labels , 'True positive':tp,'True negative':tn,'False positive':fp,'False negative':fn}
evaluation = pd.DataFrame(data, columns = ['labels','True positive','True negative','False positive','False negative'])
print("Evaluation: ")
evaluation

# %%
cm = np.zeros((12,12))
for i in range(numberOfClasses):
    cm[i,i] = evaluation.loc[i]['True positive']
    
for i in range(numberOfClasses):
    for j in range(numberOfClasses):
        temp = 0
        for k in range(len(yTest)):
            if(yTest[k]==i and prediction[k]==j):
                temp += 1
        cm[i,j]=temp

# %%
pltu.plotConfusionMatrix(cm, labels, "confusion_matrix_2", "images_point_threeplus/")
